# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# '/home/usman/Documents/Smart-Meter-analysis'

# %%
df = pd.read_csv('/home/usman/Documents/Smart-Meter-analysis/weekly_avg_avg_long.csv')

# %%
df.shape
# Out:
# (5559, 338)

# %%
df =  df.iloc[:,1:]

# %%
# get a a flavour of the profiles
plt.figure(figsize=(12, 6), dpi=80)
plt.plot(df.iloc[:25,:-1], linewidth = 1,c= 'k')
ax = plt.gca()
ax.axes.xaxis.set_visible(False)
